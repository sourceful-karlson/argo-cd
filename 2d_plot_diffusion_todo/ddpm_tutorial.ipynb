# %%
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Visualize target and prior distributions

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Define a diffusion model

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/content/drive/MyDrive/A-DEVELOPMENT/Diffusion-Assignment1-DDPM/2d_plot_diffusion_todo')

from dataset import TwoDimDataClass, get_data_iterator
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider, Output
from IPython.display import display, clear_output
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
import io

target_ds = TwoDimDataClass(dataset_type='swiss_roll',
                            N=1000000,
                            batch_size=256)

prior_ds = TwoDimDataClass(dataset_type='gaussian_centered',
                           N=1000000,
                           batch_size=256)

num_vis_particles = 500
sample_f = target_ds[0:num_vis_particles]
sample_b = prior_ds[0:num_vis_particles]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.scatter(sample_f[:, 0], sample_f[:, 1], alpha=0.6)
ax.scatter(sample_b[:, 0], sample_b[:, 1], alpha=0.6)
ax.grid(False)
ax.set_aspect('equal', adjustable='box')
strtitle = "Target and prior distributions"
ax.set_title(strtitle)
ax.legend(['Target', 'Prior (=$\mathcal{N}(\mathbf{0}, \mathbf{I})$)'])

# %%
from network import SimpleNet
from ddpm import BaseScheduler, DiffusionModule

# hyperparameters #
# Don't change it
device = "cuda:0"
config = {
    "num_diffusion_steps": 1000,
    "dim_hids": [128, 128, 128],
    "lr": 1e-3,
    "batch_size": 128,
    "num_train_iters": 5000,
    "device": device,
}

###################

def build_ddpm(config):
    network = SimpleNet(dim_in=2,
                        dim_out=2,
                        dim_hids=config["dim_hids"],
                        num_timesteps=config["num_diffusion_steps"]
                       )
    var_scheduler = BaseScheduler(config["num_diffusion_steps"])

    ddpm = DiffusionModule(network, var_scheduler).to(config["device"])
    return ddpm

ddpm = build_ddpm(config)

# %% [markdown]
# # Visualize q(x_t)

# %%
fig, axs = plt.subplots(1, 10, figsize=(28, 3))
for i, t in enumerate(range(0, 500, 50)):
    x_t = ddpm.q_sample(target_ds[:num_vis_particles].to(device), (torch.ones(num_vis_particles) * t).to(device))
    x_t = x_t.cpu()
    axs[i].scatter(x_t[:,0], x_t[:,1], color='white',edgecolor='gray', s=5)
    axs[i].set_axis_off()
    axs[i].set_title('$q(\mathbf{x}_{'+str(t)+'})$')

# %%
# You should be able to see the distributions as below.
vis_qs = Image.open("drive/MyDrive/A-DEVELOPMENT/Diffusion-Assignment1-DDPM/assets/images/qs.png")
display(vis_qs)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1189x157>

# %% [markdown]
# # Training

# %%
def figure2image(fig):
    buf = io.BytesIO()
    fig.savefig(buf)
    buf.seek(0)
    img = Image.open(buf)
    return img

# Initialize the model.
ddpm = build_ddpm(config)

pbar = tqdm(range(config["num_train_iters"]))
optimizer = torch.optim.Adam(ddpm.parameters(), lr=config["lr"])
train_dl = torch.utils.data.DataLoader(target_ds, batch_size=config["batch_size"])
train_iter = get_data_iterator(train_dl)

losses = []
images = []
try:
    for step in pbar:
        optimizer.zero_grad()

        batch_x = next(train_iter)
        batch_x = batch_x.to(device)
        loss = ddpm.compute_loss(batch_x)

        loss.backward()
        optimizer.step()
        pbar.set_description(f"loss: {loss.item():.4f}")

        losses.append(loss.item())

        if step % 4999 == 0:
            with torch.no_grad():
                ####
                # NOTE: If you haven't implemented the `ddim_p_sample_loop` method,
                # use the `p_sample_loop` method instead.
                x0 = ddpm.p_sample_loop(shape=(num_vis_particles, 2)).cpu()


                # x0 = ddpm.ddim_p_sample_loop(shape=(num_vis_particles, 2)).cpu()
                ####
                fig, ax = plt.subplots(1,1)
                ax.scatter(x0[:,0], x0[:,1])
                ax.set_title(f"Samples at {step}-iteration")
                clear_output(wait=True)
                plt.show()
                img = figure2image(fig)
                images.append(img)

except KeyboardInterrupt:
    pass
finally:
    if len(images) > 0:
        slider = IntSlider(min=0, max=len(images)-1, step=1, value=1)
        output = Output()
        def display_image(index):
            with output:
                output.clear_output(wait=True)
                display(images[index])
        interact(display_image, index=slider)
        display(output)
        plt.plot(losses)
        plt.title("Loss curve")
# Out:
# loss: 0.8359:   0%|          | 0/5000 [00:00<?, ?it/s]
# tensor(0.2213, device='cuda:0')
# result_factor[0][0] tensor(157.4104, device='cuda:0')
# result[0][0] tensor(0.2212, device='cuda:0')
# noise[0][0] tensor(-0.7882, device='cuda:0')
# tensor(34.7145, device='cuda:0')
# result_factor[0][0] tensor(155.8284, device='cuda:0')
# result[0][0] tensor(34.7145, device='cuda:0')
# noise[0][0] tensor(1.0548, device='cuda:0')
# tensor(5409.6489, device='cuda:0')
# result_factor[0][0] tensor(154.2638, device='cuda:0')
# result[0][0] tensor(5409.6479, device='cuda:0')
# noise[0][0] tensor(-1.7275, device='cuda:0')
# tensor(834512.6250, device='cuda:0')
# result_factor[0][0] tensor(152.7165, device='cuda:0')
# result[0][0] tensor(834512.5625, device='cuda:0')
# noise[0][0] tensor(-0.4750, device='cuda:0')
# tensor(1.2744e+08, device='cuda:0')
# result_factor[0][0] tensor(151.1862, device='cuda:0')
# result[0][0] tensor(1.2744e+08, device='cuda:0')
# noise[0][0] tensor(-0.1630, device='cuda:0')
# tensor(1.9268e+10, device='cuda:0')
# result_factor[0][0] tensor(149.6728, device='cuda:0')
# result[0][0] tensor(1.9268e+10, device='cuda:0')
# noise[0][0] tensor(0.1863, device='cuda:0')
# tensor(2.8839e+12, device='cuda:0')
# result_factor[0][0] tensor(148.1760, device='cuda:0')
# result[0][0] tensor(2.8839e+12, device='cuda:0')
# noise[0][0] tensor(1.3083, device='cuda:0')
# tensor(4.2732e+14, device='cuda:0')
# result_factor[0][0] tensor(146.6957, device='cuda:0')
# result[0][0] tensor(4.2732e+14, device='cuda:0')
# noise[0][0] tensor(0.0267, device='cuda:0')
# tensor(6.2686e+16, device='cuda:0')
# result_factor[0][0] tensor(145.2317, device='cuda:0')
# result[0][0] tensor(6.2686e+16, device='cuda:0')
# noise[0][0] tensor(0.0551, device='cuda:0')
# tensor(9.1040e+18, device='cuda:0')
# result_factor[0][0] tensor(143.7837, device='cuda:0')
# result[0][0] tensor(9.1040e+18, device='cuda:0')
# noise[0][0] tensor(0.2784, device='cuda:0')
# tensor(1.3090e+21, device='cuda:0')
# result_factor[0][0] tensor(142.3517, device='cuda:0')
# result[0][0] tensor(1.3090e+21, device='cuda:0')
# noise[0][0] tensor(0.3016, device='cuda:0')
# tensor(1.8634e+23, device='cuda:0')
# result_factor[0][0] tensor(140.9353, device='cuda:0')
# result[0][0] tensor(1.8634e+23, device='cuda:0')
# noise[0][0] tensor(0.2247, device='cuda:0')
# tensor(2.6262e+25, device='cuda:0')
# result_factor[0][0] tensor(139.5344, device='cuda:0')
# result[0][0] tensor(2.6262e+25, device='cuda:0')
# noise[0][0] tensor(-0.0260, device='cuda:0')
# tensor(3.6644e+27, device='cuda:0')
# result_factor[0][0] tensor(138.1489, device='cuda:0')
# result[0][0] tensor(3.6644e+27, device='cuda:0')
# noise[0][0] tensor(0.1598, device='cuda:0')
# tensor(5.0623e+29, device='cuda:0')
# result_factor[0][0] tensor(136.7785, device='cuda:0')
# result[0][0] tensor(5.0623e+29, device='cuda:0')
# noise[0][0] tensor(-1.1277, device='cuda:0')
# tensor(6.9242e+31, device='cuda:0')
# result_factor[0][0] tensor(135.4230, device='cuda:0')
# result[0][0] tensor(6.9242e+31, device='cuda:0')
# noise[0][0] tensor(1.6809, device='cuda:0')
# tensor(9.3769e+33, device='cuda:0')
# result_factor[0][0] tensor(134.0824, device='cuda:0')
# result[0][0] tensor(9.3769e+33, device='cuda:0')
# noise[0][0] tensor(-1.1401, device='cuda:0')
# tensor(1.2573e+36, device='cuda:0')
# result_factor[0][0] tensor(132.7564, device='cuda:0')
# result[0][0] tensor(1.2573e+36, device='cuda:0')
# noise[0][0] tensor(1.2608, device='cuda:0')
# tensor(1.6691e+38, device='cuda:0')
# result_factor[0][0] tensor(131.4448, device='cuda:0')
# result[0][0] tensor(nan, device='cuda:0')
# noise[0][0] tensor(0.5725, device='cuda:0')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-8cab4daacd0f> in <cell line: 18>()
#      35                 # NOTE: If you haven't implemented the `ddim_p_sample_loop` method,
#      36                 # use the `p_sample_loop` method instead.
# ---> 37                 x0 = ddpm.p_sample_loop(shape=(num_vis_particles, 2)).cpu()
#      38
#      39
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /content/drive/MyDrive/A-DEVELOPMENT/Diffusion-Assignment1-DDPM/2d_plot_diffusion_todo/ddpm.py in p_sample_loop(self, shape)
#     162           x_t = self.p_sample(x_t, t)
#     163           if torch.isnan(x_t[0][0]):
# --> 164             raise "Nan"
#     165
#     166         x0_pred = x_t
#
# TypeError: exceptions must derive from BaseException

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## DDPM sampling (Assignment 1)

# %%
# You will get full credits if your chamfer distance is lower than 20.
from chamferdist import chamfer_distance

num_eval_particles = 2048
pc_ref = target_ds[:num_eval_particles]
pc_gen = ddpm.p_sample_loop(shape=(num_eval_particles, 2))

pc_gen = pc_gen.reshape(1, num_eval_particles, 2)
pc_ref = pc_ref.reshape(1, num_eval_particles, 2)
with torch.no_grad():
    cd = chamfer_distance(
            pc_gen.reshape(-1, 2).cpu().numpy(),
            pc_ref.reshape(-1, 2).cpu().numpy(),
        )
    print(f"DDPM Chamfer Distance: {cd.item():.4f}")

# Visualize samples with the target distribution.
pc_gen = pc_gen.reshape(num_eval_particles, 2).cpu().numpy()
pc_ref = pc_ref.reshape(num_eval_particles, 2).cpu().numpy()

fig, ax = plt.subplots(1,1)
ax.scatter(pc_ref[:,0], pc_ref[:,1], alpha=0.1, label="target distribution")
ax.scatter(pc_gen[:,0], pc_gen[:,1], alpha=0.1, label="samples")
ax.legend()
plt.show()
# Out:
# DDPM Chamfer Distance: nan
